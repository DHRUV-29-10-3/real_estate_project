# %%
import pandas as pd 
import numpy as np 
import re

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('gurgaon_flats.csv',index_col=0)

# %%
df.sample(10)
# Out:
#                                       property_name property_type  \
# 2318               1 BHK Flat in Valley View Estate          flat
# 677                 3 BHK Flat in Sector 89 Gurgaon          flat
# 1109  2 Bedroom House for sale in Sector 31 Gurgaon         house
# 1755                3 BHK Flat in Sector 65 Gurgaon          flat
# 1104               2 BHK Flat in Sector 108 Gurgaon          flat
# 1627                3 BHK Flat in Sector 92 Gurgaon          flat
# 1266                            2 BHK Flat in Sohna          flat
# 1048               1 BHK Flat in Sector 104 Gurgaon          flat
# 870             3 BHK Flat in Mehrauli Gurgaon Road          flat
# 3255                3 BHK Flat in Sector 53 Gurgaon          flat
#
#                                       society  price  price_per_sqft  \
# 2318                       valley view estate   0.38          6089.0
# 677                             m3m soulitude   1.33         16985.0
# ...

# %%
df.shape
# Out:
# (3940, 20)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# property_name         0
# property_type         0
# society             562
# price                 0
# price_per_sqft        0
# area                  0
# areaWithType          0
# bedRoom               0
# bathroom              0
# balcony               0
# additionalRoom        0
# address              11
# floorNum             20
# facing             1170
# agePossession         1
# nearbyLocations     205
# description           0
# furnishDetails     1026
# features            704
# rating              448
# dtype: int64

# %%
df.head(1)
# Out:
#                       property_name property_type                   society  \
# 0  2 BHK Flat in Sector 99A Gurgaon          flat  pareena laxmi apartments
#
#    price  price_per_sqft   area  \
# 0   0.32          5521.0  580.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 575(53.42 sq.m.)Carpet are...        2         2
#
#   balcony additionalRoom                               address  floorNum  \
# 0       1  not available  Sector 99A Gurgaon, Gurgaon, Haryana       2.0
#
#   facing    agePossession                                    nearbyLocations  \
# 0    NaN  0 to 1 Year Old  ['Dwarka Expy', 'Govt. Sr. Sec. School', 'Exce...
#
#                                          description furnishDetails  \
# 0  This lovely 2 bhk apartment/flat in sector 99a...            NaN
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Lift(s)', 'S...
#
# ...

# %%
df.insert(loc = 3, column = 'sector', value = df['property_name'].str.split('in').str.get(1).str.replace('Gurgaon', '').str.strip().str.lower())

# %%
df.sample(5)
# Out:
#                          property_name property_type  \
# 602      3 BHK Flat in Nirvana Country          flat
# 828   3 BHK Flat in Sector 37C Gurgaon          flat
# 594   3 BHK Flat in Sector 37D Gurgaon          flat
# 2166   4 BHK Flat in Sector 49 Gurgaon          flat
# 1730     2 BHK Flat in Sector-33 Sohna          flat
#
#                          society           sector  price  price_per_sqft  \
# 602              the close north  nirvana country   2.65         11276.0
# 828                    ild grand       sector 37c   1.35          7142.0
# 594   ramprastha the edge towers       sector 37d   1.00          5649.0
# 2166                 vatika city        sector 49   3.60         11920.0
# 1730          godrej nature plus  sector-33 sohna   1.40          9333.0
#
#         area                                       areaWithType  bedRoom  \
# 602   2350.0  Super Built up area 2605(242.01 sq.m.)Built Up...        3
# ...

# %%
df['society'].fillna('independent', inplace = True)
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_18588\2071796649.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['society'].fillna('independent', inplace = True)

# %%
df[~df['sector'].str.startswith('s')]['sector'].value_counts()
# Out:
# sector
# nirvana country                                              52
# palam vihar                                                  50
# dlf phase 1                                                  43
# dlf phase 2                                                  41
# laxman vihar                                                 26
# dlf phase 4                                                  25
# dlf phase 3                                                  21
# dlf phase 5                                                  14
# rajendra park                                                14
# gwal pahari                                                  14
# laxman vihar phase 2                                         13
# uppals southend                                              12
# ashok vihar phase 3 extension                                11
# ashok vihar phase 2                                           9
# dwarka expressway                                             8
# ...

# %%
df['sector'] = df['sector'].str.replace('nirvana country', 'Sector 50', regex=True)
df['sector'] = df['sector'].str.replace('palam vihar', 'Sector 2', regex=True)
df['sector'] = df['sector'].str.replace('dlf phase 1', 'Sector 26', regex=True)
df['sector'] = df['sector'].str.replace('dlf phase 2', 'Sector 25', regex=True)
df['sector'] = df['sector'].str.replace('laxman vihar', 'Sector 3', regex=True)
df['sector'] = df['sector'].str.replace('dlf phase 4', 'Sector 28', regex=True)
df['sector'] = df['sector'].str.replace('dlf phase 3', 'Sector 24', regex=True)
df['sector'] = df['sector'].str.replace('dlf phase', 'Sector 27', regex=True)
df['sector'] = df['sector'].str.replace('rajendra park', 'Sector 105', regex=True)
df['sector'] = df['sector'].str.replace('gwal pahari', 'Sector 2A', regex=True)
df['sector'] = df['sector'].str.replace('laxman vihar phase 2', 'Sector 3A', regex=True)
df['sector'] = df['sector'].str.replace('uppals southend', 'Sector 49', regex=True)
df['sector'] = df['sector'].str.replace('ashok vihar phase 3 extension', 'Sector 5', regex=True)
df['sector'] = df['sector'].str.replace('ashok vihar phase 2', 'Sector 4', regex=True)
df['sector'] = df['sector'].str.replace('dwarka expressway', 'Sector 37D', regex=True)
df['sector'] = df['sector'].str.replace('palam vihar extension', 'Sector 23', regex=True)
df['sector'] = df['sector'].str.replace('mehrauli road', 'Sector 14', regex=True)
df['sector'] = df['sector'].str.replace('malibu town', 'Sector 47', regex=True)
df['sector'] = df['sector'].str.replace('c block sushant lok phase 1', 'Sector 43', regex=True)
df['sector'] = df['sector'].str.replace('new colony', 'Sector 7', regex=True)
df['sector'] = df['sector'].str.replace('mianwali colony', 'Sector 12', regex=True)
df['sector'] = df['sector'].str.replace('jacobpura', 'Sector 12A', regex=True)
df['sector'] = df['sector'].str.replace('ashok vihar', 'Sector 5', regex=True)
df['sector'] = df['sector'].str.replace('jyoti park', 'Sector 7', regex=True)
df['sector'] = df['sector'].str.replace('rajiv nagar', 'Sector 13', regex=True)
df['sector'] = df['sector'].str.replace('new palam vihar', 'Sector 110', regex=True)
df['sector'] = df['sector'].str.replace('ansal plaza', 'Sector 22', regex=True)
df['sector'] = df['sector'].str.replace('dayanand colony', 'Sector 6', regex=True)
df['sector'] = df['sector'].str.replace('arjun nagar', 'Sector 8', regex=True)
df['sector'] = df['sector'].str.replace('greenwood city', 'Sector 45', regex=True)
df['sector'] = df['sector'].str.replace('manesar', 'IMT Manesar', regex=True)
df['sector'] = df['sector'].str.replace('chakkarpur', 'Sector 28', regex=True)
df['sector'] = df['sector'].str.replace('ravi nagar', 'Sector 16', regex=True)
df['sector'] = df['sector'].str.replace('bhim nagar', 'Sector 5', regex=True)
df['sector'] = df['sector'].str.replace('adarsh nagar', 'Sector 12', regex=True)
df['sector'] = df['sector'].str.replace('baldev nagar', 'Sector 7', regex=True)
df['sector'] = df['sector'].str.replace('bhondsi', 'Near Sohna Road', regex=True)
df['sector'] = df['sector'].str.replace('imt manesar', 'Sector 1', regex=True)
df['sector'] = df['sector'].str.replace('valley view estate', 'Sector 30', regex=True)
df['sector'] = df['sector'].str.replace('devilal colony', 'Sector 9', regex=True)
df['sector'] = df['sector'].str.replace('madanpuri', 'Sector 7', regex=True)
df['sector'] = df['sector'].str.replace('krishna colony', 'Sector 9A', regex=True)
df['sector'] = df['sector'].str.replace('vishnu garden', 'Sector 37', regex=True)
df['sector'] = df['sector'].str.replace('dharam colony', 'Sector 110', regex=True)
df['sector'] = df['sector'].str.replace('garhi harsaru', 'Sector 99', regex=True)
df['sector'] = df['sector'].str.replace('mg road', 'Sector 25A', regex=True)
df['sector'] = df['sector'].str.replace('laxmi garden', 'Sector 11', regex=True)
df['sector'] = df['sector'].str.replace('gandhi nagar', 'Sector 11', regex=True)
df['sector'] = df['sector'].str.replace('maruti kunj', 'Sector 69', regex=True)
df['sector'] = df['sector'].str.replace('patel nagar', 'Sector 15', regex=True)
df['sector'] = df['sector'].str.replace('prem nagar', 'Sector 13', regex=True)
df['sector'] = df['sector'].str.replace('ambience island', 'Near Cyber City', regex=True)
df['sector'] = df['sector'].str.replace('iffco chowk', 'Sector 29', regex=True)
df['sector'] = df['sector'].str.replace('golf course road', 'Sector 42', regex=True)
df['sector'] = df['sector'].str.replace('golf course ext road', 'Sector 58', regex=True)
df['sector'] = df['sector'].str.replace('kanahi', 'Sector 32', regex=True)
df['sector'] = df['sector'].str.replace('urban estate, sector 5', 'Sector 5', regex=True)
df['sector'] = df['sector'].str.replace('mayfield garden', 'Sector 50', regex=True)
df['sector'] = df['sector'].str.replace('pataudi road', 'Sector 86', regex=True)
df['sector'] = df['sector'].str.replace('tekchand nagar', 'Sector 39', regex=True)
df['sector'] = df['sector'].str.replace('ansal\'s palam vihar', 'Sector 2A', regex=True)
df['sector'] = df['sector'].str.replace('heritage city', 'Sector 25', regex=True)

# %%
df['sector'] = df['sector'].str.lower()

# %%
df[~df['sector'].str.startswith('s')]['sector'].value_counts()
# Out:
# sector
# mehrauli  road                                               8
# new sector 2                                                 5
# imt manesar                                                  5
# near sohna road                                              4
# imt imt manesar                                              4
# new                                                          4
# b block sushant lok phase 1                                  3
# a block sushant lok phase 1                                  3
# near cyber city                                              2
# west sector 13                                               2
# new sector 2 phase 1                                         2
# rajiv chowk                                                  2
# manohar nagar                                                2
# pratap nagar                                                 2
# rosewood                                                     2
# ...

# %%
df['sector'] = df['sector'].str.replace('mehrauli  road', 'Sector 14', regex=True)
df['sector'] = df['sector'].str.replace('new sector 2', 'Sector 2', regex=True)
df['sector'] = df['sector'].str.replace('imt manesar', 'Sector 1', regex=True)
df['sector'] = df['sector'].str.replace('near sohna road', 'Sector 68', regex=True)
df['sector'] = df['sector'].str.replace('imt imt manesar', 'Sector 1', regex=True)
df['sector'] = df['sector'].str.replace('b block sushant lok phase 1', 'Sector 43', regex=True)
df['sector'] = df['sector'].str.replace('a block sushant lok phase 1', 'Sector 43', regex=True)
df['sector'] = df['sector'].str.replace('near cyber city', 'Sector 25', regex=True)
df['sector'] = df['sector'].str.replace('west sector 13', 'Sector 13', regex=True)
df['sector'] = df['sector'].str.replace('new sector 2 phase 1', 'Sector 2', regex=True)
df['sector'] = df['sector'].str.replace('rajiv chowk', 'Sector 29', regex=True)
df['sector'] = df['sector'].str.replace('manohar nagar', 'Sector 12', regex=True)
df['sector'] = df['sector'].str.replace('pratap nagar', 'Sector 8', regex=True)
df['sector'] = df['sector'].str.replace('rosewood', 'Sector 49', regex=True)
df['sector'] = df['sector'].str.replace('faridabad road', 'Sector 37', regex=True)
df['sector'] = df['sector'].str.replace('nars', 'Sector 1', regex=True)
df['sector'] = df['sector'].str.replace('hira nagar', 'Sector 2', regex=True)
df['sector'] = df['sector'].str.replace('new sector 2 phase 2', 'Sector 2', regex=True)
df['sector'] = df['sector'].str.replace('block a surya vihar', 'Sector 30', regex=True)
df['sector'] = df['sector'].str.replace('mohan nagar', 'Sector 11', regex=True)
df['sector'] = df['sector'].str.replace('lajpat nagar', 'Sector 15', regex=True)
df['sector'] = df['sector'].str.replace('daulatabad', 'Sector 103', regex=True)
df['sector'] = df['sector'].str.replace(', delhi ncr', 'Sector 22', regex=True)
df['sector'] = df['sector'].str.replace('farukhnagar', 'Sector 95', regex=True)
df['sector'] = df['sector'].str.replace('bissar', 'Sector 91', regex=True)
df['sector'] = df['sector'].str.replace('new basti', 'Sector 32', regex=True)
df['sector'] = df['sector'].str.replace('bhawani enclave', 'Sector 9', regex=True)
df['sector'] = df['sector'].str.replace('acharya puri', 'Sector 4', regex=True)
df['sector'] = df['sector'].str.replace('block h sector 5 phase iii extension', 'Sector 5', regex=True)
df['sector'] = df['sector'].str.replace('near khandsa road', 'Sector 37', regex=True)
df['sector'] = df['sector'].str.replace('b1 block sector 57', 'Sector 57', regex=True)
df['sector'] = df['sector'].str.replace('rattan garden', 'Sector 37', regex=True)
df['sector'] = df['sector'].str.replace('damdma', 'Sector 104', regex=True)
df['sector'] = df['sector'].str.replace('alipur', 'Sector 108', regex=True)
df['sector'] = df['sector'].str.replace('block g sector-57', 'Sector 57', regex=True)
df['sector'] = df['sector'].str.replace('v block sector 24', 'Sector 24', regex=True)
df['sector'] = df['sector'].str.replace('vir nagar', 'Sector 6', regex=True)
df['sector'] = df['sector'].str.replace('near sector 1 market', 'Sector 1', regex=True)
df['sector'] = df['sector'].str.replace('godrej aria , sector 79 ,', 'Sector 79', regex=True)
df['sector'] = df['sector'].str.replace('carterpuri village', 'Sector 23', regex=True)
df['sector'] = df['sector'].str.replace('new sector 7', 'Sector 7', regex=True)
df['sector'] = df['sector'].str.replace('civil l', 'Sector 9A', regex=True)
df['sector'] = df['sector'].str.replace('begampur khatola', 'Sector 35', regex=True)
df['sector'] = df['sector'].str.replace('mahavir pura', 'Sector 37', regex=True)
df['sector'] = df['sector'].str.replace('park view', 'Sector 48', regex=True)
df['sector'] = df['sector'].str.replace('kheri', 'Sector 88', regex=True)
df['sector'] = df['sector'].str.replace('ravi nager basai road', 'Sector 9', regex=True)
df['sector'] = df['sector'].str.replace('near euro', 'Sector 33', regex=True)
df['sector'] = df['sector'].str.replace('hsiidc plot sector 1 imt imt manesar', 'Sector 1', regex=True)
df['sector'] = df['sector'].str.replace('huda saraswati vihar', 'Sector 10A', regex=True)
df['sector'] = df['sector'].str.replace('khandsa', 'Sector 37', regex=True)
df['sector'] = df['sector'].str.replace('near nand hospital', 'Sector 5', regex=True)
df['sector'] = df['sector'].str.replace('ram nagar', 'Sector 11', regex=True)
df['sector'] = df['sector'].str.replace('g block dlf city phase 1', 'Sector 26', regex=True)
df['sector'] = df['sector'].str.replace('anand garden, sector-105', 'Sector 105', regex=True)
df['sector'] = df['sector'].str.replace('jat colony,fazilpur/taj nagar road', 'Sector 72', regex=True)
df['sector'] = df['sector'].str.replace('cyber city', 'Sector 25A', regex=True)
df['sector'] = df['sector'].str.replace('garauli kalan', 'Sector 107', regex=True)
df['sector'] = df['sector'].str.replace('bptp', 'Sector 37D', regex=True)
df['sector'] = df['sector'].str.replace('devi lal colony gali no 12 gurgaon nr omkar public school', 'Sector 9', regex=True)
df['sector'] = df['sector'].str.replace('old delhi road, opp sector-14', 'Sector 14', regex=True)
df['sector'] = df['sector'].str.replace('lucknow', 'Sector 48', regex=True)
df['sector'] = df['sector'].str.replace('laxmna vihar, phase 2', 'Sector 3A', regex=True)
df['sector'] = df['sector'].str.replace('dhankot', 'Sector 102', regex=True)
df['sector'] = df['sector'].str.replace('ats marigold', 'Sector 89A', regex=True)
df['sector'] = df['sector'].str.replace('near pataudi chowk', 'Sector 86', regex=True)
df['sector'] = df['sector'].str.replace('bhora kalan', 'Sector 95A', regex=True)
df['sector'] = df['sector'].str.replace('ansal\'s sector 2', 'Sector 2', regex=True)
df['sector'] = df['sector'].str.replace('bhimgarh kheri phase 3', 'Sector 10', regex=True)
df['sector'] = df['sector'].str.replace('hno 13 sagar enclave sura', 'Sector 108', regex=True)
df['sector'] = df['sector'].str.replace('imt sector 1', 'Sector 1', regex=True)

# %%
df['sector'] = df['sector'].str.lower().str.strip()

# %%
df[~df['sector'].str.startswith('s')]['sector'].value_counts()
# Out:
# sector
# new                                    4
# imt sector 1                           4
# hsiidc plot sector 1 imt sector 1      1
# part 3 sector 5                        1
# om nagar                               1
# rajiv colony                           1
# bhimgarh sector 88 phase 3             1
# gopal nagar, garhi ghasita, sonipat    1
# mahasector 11, rajendra place          1
# Name: count, dtype: int64

# %%
df['sector'] = df['sector'].str.replace('hsiidc plot sector 1 sector 1', 'sector 1', regex=True)
df['sector'] = df['sector'].str.replace('hsiidc plot sector 1 sector 1', 'sector 1', regex=True)
df['sector'] = df['sector'].str.replace('part 3 sector 5', 'sector 5', regex=True)
df['sector'] = df['sector'].str.replace('om nagar', 'sector 11', regex=True)
df['sector'] = df['sector'].str.replace('rajiv colony', 'sector 33', regex=True)
df['sector'] = df['sector'].str.replace('bhimgarh sector 88 phase 3', 'sector 88', regex=True)
df['sector'] = df['sector'].str.replace('gopal nagar, garhi ghasita, sonipat', 'sector 12', regex=True)
df['sector'] = df['sector'].str.replace('mahasector 11, rajendra place', 'sector 11', regex=True)

# %%
df.head()
# Out:
#                                  property_name property_type  \
# 0             2 BHK Flat in Sector 99A Gurgaon          flat
# 1              3 BHK Flat in Sector 56 Gurgaon          flat
# 2             2 BHK Flat in Sector 108 Gurgaon          flat
# 3             3 BHK Flat in Sector 104 Gurgaon          flat
# 4  6 Bedroom House for sale in Nirvana Country         house
#
#                     society      sector  price  price_per_sqft         area  \
# 0  pareena laxmi apartments  sector 99a   0.32          5521.0   580.000000
# 1           kiran residency   sector 56   1.55          7750.0  2000.000000
# 2           raheja vedaanta  sector 108   1.00          4854.0  2060.000000
# 3               ats triumph  sector 104   1.83          7991.0  2290.000000
# 4               independent   sector 50  13.20         27155.0  4860.983244
#
#                                         areaWithType  bedRoom  bathroom  \
# ...

# %%
df[df['sector'] == 'new']
# Out:
#                   property_name property_type                       society  \
# 483   4 BHK Flat in New Gurgaon          flat                    sare homes
# 500   4 BHK Flat in New Gurgaon          flat                        dlf 76
# 809   2 BHK Flat in New Gurgaon          flat  takshila heights sector 37 c
# 3685  2 BHK Flat in New Gurgaon          flat                   green court
#
#      sector  price  price_per_sqft    area  \
# 483     new   0.85          4786.0  1776.0
# 500     new   4.00         11428.0  3500.0
# 809     new   0.67          5583.0  1200.0
# 3685    new   0.38          5507.0   690.0
#
#                                 areaWithType  bedRoom  bathroom balcony  \
# 483      Super Built up area 1776(165 sq.m.)        4         4       3
# 500         Carpet area: 3500 (325.16 sq.m.)        4         4       2
# 809   Super Built up area 1200(111.48 sq.m.)        2         2       2
# 3685           Carpet area: 690 (64.1 sq.m.)        2         2       1
#
# ...

# %%
df[df['society'] == 'sare homes']['sector'] = df[df['society'] == 'sare homes']['sector'].str.replace('new', 'sector 92')
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_18588\339473534.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['society'] == 'sare homes']['sector'] = df[df['society'] == 'sare homes']['sector'].str.replace('new', 'sector 92')

# %%
df[df['society'] == 'dlf 76']['sector']['sector'] = df[df['society'] == 'dlf 76']['sector'].str.replace('new', 'sector 76')
df[df['society'] == 'takshila heights sector 37 c']['sector'] = df[df['society'] == 'takshila heights sector 37 c']['sector'].str.replace('new', 'sector 37c')
df[df['society'] == 'green court']['sector'] = df[df['society'] == 'green court']['sector'].str.replace('new', 'sector 90')
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_18588\2586139777.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['society'] == 'dlf 76']['sector']['sector'] = df[df['society'] == 'dlf 76']['sector'].str.replace('new', 'sector 76')
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_18588\2586139777.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['society'] == 'takshila heights sector 37 c']['sector'] = df[df['society'] == 'takshila heights sector 37 c']['sector'].str.replace('new', 'sector 37c')
# ...

# %%
df.head()
# Out:
#                                  property_name property_type  \
# 0             2 BHK Flat in Sector 99A Gurgaon          flat
# 1              3 BHK Flat in Sector 56 Gurgaon          flat
# 2             2 BHK Flat in Sector 108 Gurgaon          flat
# 3             3 BHK Flat in Sector 104 Gurgaon          flat
# 4  6 Bedroom House for sale in Nirvana Country         house
#
#                     society      sector  price  price_per_sqft         area  \
# 0  pareena laxmi apartments  sector 99a   0.32          5521.0   580.000000
# 1           kiran residency   sector 56   1.55          7750.0  2000.000000
# 2           raheja vedaanta  sector 108   1.00          4854.0  2060.000000
# 3               ats triumph  sector 104   1.83          7991.0  2290.000000
# 4               independent   sector 50  13.20         27155.0  4860.983244
#
#                                         areaWithType  bedRoom  bathroom  \
# ...

# %%
df[~df['sector'].str.contains('sector')]['sector'].value_counts()
# Out:
# sector
# sohna                  163
# sushant lok phase 1     31
# sushant lok phase 3     16
# sohna road              12
# south city 1             9
# surat nagar 1            7
# sushant lok phase 2      5
# subhash nagar            5
# saraswati vihar          5
# shivaji nagar            4
# suncity                  4
# new                      4
# shivpuri                 4
# surya vihar              4
# sushant lok              2
# sispal vihar             2
# shankar vihar            2
# surat nagar              2
# samaspur                 2
# sheetla colony           2
# surat nagar phase 2      2
# shakti nagar             2
# shanti nagar             2
# sohna  road              2
# south city               1
# sadar bazar              1
# saraswati enclave        1
# shivji park colony       1
# sultanpur                1
# sai kunj                 1
# Name: count, dtype: int64

# %%
df['sector'] = df['sector'].str.replace('dlf 76', 'Sector 76', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('sohna', 'Sector 48', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('sushant lok phase 1', 'Sector 43', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('sushant lok phase 3', 'Sector 57', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('sohna road', 'Sector 47', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('south city 1', 'Sector 40', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('surat nagar 1', 'Sector 24', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('sushant lok phase 2', 'Sector 57A', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('subhash nagar', 'Sector 9', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('saraswati vihar', 'Sector 8', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('shivaji nagar', 'Sector 13', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('suncity', 'Sector 54', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('new', 'Sector 12', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('shivpuri', 'Sector 30', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('surya vihar', 'Sector 9A', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('sushant lok', 'Sector 43', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('sispal vihar', 'Sector 14', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('shankar vihar', 'Sector 7', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('surat nagar', 'Sector 24', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('samaspur', 'Sector 49', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('sheetla colony', 'Sector 35', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('surat nagar phase 2', 'Sector 25', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('shakti nagar', 'Sector 16', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('shanti nagar', 'Sector 11', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('sohna  road', 'Sector 47', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('south city', 'Sector 40', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('sadar bazar', 'Sector 14', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('saraswati enclave', 'Sector 6', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('shivji park colony', 'Sector 18', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('sultanpur', 'Sector 65', regex=True).str.lower()
df['sector'] = df['sector'].str.replace('sai kunj', 'Sector 22', regex=True).str.lower()

# %%
df['sector'].value_counts()
# Out:
# sector
# sector 48              235
# sector 102             114
# sector 85              110
# sector 92              104
# sector 69               97
# sector 65               91
# sector 81               90
# sector 90               90
# sector 109              88
# sector 79               81
# sector 37d              77
# sector 2                75
# sector 83               69
# sector 86               69
# sector 104              67
# sector 50               67
# sector 89               64
# sector 107              61
# sector 108              60
# sector 95               59
# sector 56               57
# sector 43               55
# sector 3                55
# sector 70a              54
# sector 70               53
# sector 37c              53
# sector 49               52
# sector 84               51
# sector 26               51
# sector-33 sector 48     51
# sector 67               48
# sector 103              47
# sector 25               44
# sector 113              43
# ...

# %%
df['sector'] = df['sector'].str.strip().str.replace('sector 5 chowk', 'sector 5')
df['sector'] = df['sector'].str.strip().str.replace('sector 3, railway road,', 'sector 3')
df['sector'] = df['sector'].str.strip().str.replace('sector 7, sector 7', 'sector 7')
df['sector'] = df['sector'].str.strip().str.replace('hsiidc plot sector 1 imt sector 1', 'sector 1')
df['sector'] = df['sector'].str.strip().str.replace('saroop garden sector 105', 'sector 105')
df['sector'] = df['sector'].str.strip().str.replace('sector 21a faridabad', 'sector 21')
df['sector'] = df['sector'].str.strip().str.replace('sector 5 phase i', 'sector 5')
df['sector'] = df['sector'].str.strip().str.replace('sector-7 hous', 'sector 7')
df['sector'] = df['sector'].str.strip().str.replace('sector 4 urban estate', 'sector 4')

# %%
df['sector'] = df['sector'].str.strip().str.replace('sector 1 imt sector 1', 'sector 1')
df['sector'] = df['sector'].str.strip().str.replace('sector 27 5', 'sector 27')
df['sector'] = df['sector'].str.strip().str.replace('sector 3 phase 2', 'sector 3')
df['sector'] = df['sector'].str.strip().str.replace('sector 48 road', 'sector 48')
df['sector'] = df['sector'].str.strip().str.replace('sector 1a imt sector 1', 'sector 1')
df['sector'] = df['sector'].str.strip().str.replace('sector 2 extension', 'sector 2')
df['sector'] = df['sector'].str.strip().str.replace('sector 89 a', 'sector 89')
df['sector'] = df['sector'].str.strip().str.replace('imt sector 1', 'sector 1')
df['sector'] = df['sector'].str.strip().str.replace('sector 110 a', 'sector 110')
df['sector'] = df['sector'].str.strip().str.replace('sector 2 phase 1', 'sector 2')

# %%
df['sector'] = df['sector'].str.strip().str.replace('sec 3 bhim vihar part 1 bhimgher sector 88', 'sector 3')
df['sector'] = df['sector'].str.strip().str.replace('sector 5 phase 3', 'sector 5')
df['sector'] = df['sector'].str.strip().str.replace('sector 50 pocket h', 'sector 50')
df['sector'] = df['sector'].str.strip().str.replace('sector 12a near sector 14', 'sector 12')
df['sector'] = df['sector'].str.strip().str.replace('sector 48  road', 'sector 48')
df['sector'] = df['sector'].str.strip().str.replace('sector 24 phase 2', 'sector 24')
df['sector'] = df['sector'].str.strip().str.replace('sector 15 part 2', 'sector 15')
df['sector'] = df['sector'].str.strip().str.replace('sector 15 part 1', 'sector 15')
df['sector'] = df['sector'].str.strip().str.replace('sector 2 phase 2', 'sector 2')

# %%
df['sector'] = df['sector'].str.replace(r'(\d+)[a-zA-Z]*', r'\1', regex=True)

# %%
df['sector'].value_counts()
# Out:
# sector
# sector 48     235
# sector 37     142
# sector 102    114
# sector 85     110
# sector 70     107
# sector 92     104
# sector 69      97
# sector 65      91
# sector 2       91
# sector 81      90
# sector 90      90
# sector 109     88
# sector 79      81
# sector 33      73
# sector 67      70
# sector 83      69
# sector 86      69
# sector 95      69
# sector 104     67
# sector 50      67
# sector 89      65
# sector 82      62
# sector 107     61
# sector 108     60
# sector 3       60
# sector 56      57
# sector 43      55
# sector 49      52
# sector 99      52
# sector 84      51
# sector 26      51
# sector 25      48
# sector 103     47
# sector 1       43
# sector 113     43
# sector 66      42
# sector 61      42
# sector 9       39
# sector 106     38
# sector 5       36
# sector 7       36
# sector 28      35
# sector 24      35
# sector 68      34
# sector 12      33
# sector 63      33
# sector 57      31
# sector 54      31
# sector 72      30
# ...

# %%
df['sector'] = df['sector'].str.replace('sector-33 sector 48', 'sector 33')
df['sector'] = df['sector'].str.replace('sector 36 sector 48', 'sector 36')
df['sector'] = df['sector'].str.replace('sector-2 sector 48', 'sector 2')
df['sector'] = df['sector'].str.replace('sector-11 sector 48', 'sector 11')
df['sector'] = df['sector'].str.replace('sector-35 sector 48', 'sector 35')
df['sector'] = df['sector'].str.replace('sector-5 sector 48', 'sector 5')
df['sector'] = df['sector'].str.replace('sector-5 sector 35', 'sector 5')

# %%
df.sample(2)
# Out:
#                          property_name property_type                 society  \
# 966   3 BHK Flat in Sector 102 Gurgaon          flat  conscient heritage max
# 2317  4 BHK Flat in Sector 108 Gurgaon          flat  experion the heartsong
#
#           sector  price  price_per_sqft    area  \
# 966   sector 102   1.75          9011.0  1942.0
# 2317  sector 108   2.29          8240.0  2779.0
#
#                                 areaWithType  bedRoom  bathroom balcony  \
# 966   Super Built up area 1942(180.42 sq.m.)        3         4      3+
# 2317      Built Up area: 2779 (258.18 sq.m.)        4         5      3+
#
#      additionalRoom                                    address  floorNum  \
# 966    servant room  N/a, Sector 102 Gurgaon, Gurgaon, Haryana      13.0
# 2317   servant room       Sector 108 Gurgaon, Gurgaon, Haryana       8.0
#
#      facing    agePossession  \
# 966   North  1 to 5 Year Old
# 2317  South  1 to 5 Year Old
#
# ...

# %%
df.drop(columns = ['property_name','address','description','rating'], inplace=True)

# %%
df.sample(5)
# Out:
#      property_type                   society      sector  price  \
# 1305         house               independent   sector 39   1.70
# 3707          flat             prime habitat   sector 99   0.27
# 3227          flat   la vida by tata housing  sector 113   2.40
# 3127         house               independent    sector 5   3.75
# 2064         house  signature global city 92   sector 92   0.75
#
#       price_per_sqft         area  \
# 1305         17980.0   945.494994
# 3707          5432.0   497.000000
# 3227         10825.0  2217.000000
# 3127         11029.0  3400.126938
# 2064          7820.0   959.079284
#
#                                            areaWithType  bedRoom  bathroom  \
# 1305                         Plot area 900(83.61 sq.m.)        2         2
# 3707                     Carpet area: 497 (46.17 sq.m.)        2         2
# 3227  Super Built up area 2217(205.97 sq.m.)Built Up...        3         4
# ...

# %%
df['area'] = round(df['area'],2)

# %%
df['facing'].fillna('not available',inplace=True)
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_18588\20986712.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['facing'].fillna('not available',inplace=True)

# %%
df.to_csv('final_cleaned_file.csv')
